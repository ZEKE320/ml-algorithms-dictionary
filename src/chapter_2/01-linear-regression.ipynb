# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

X = [[10.0], [8.0], [13.0], [9.0], [11.0], [
    14.0], [6.0], [4.0], [12.0], [7.0], [5.0]]
y = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

model = LinearRegression()
model.fit(X, y)

print(model.intercept_)
print(model.coef_)
y_pred = model.predict(np.array([[0], [1]]))
print(y_pred)
# Out:
# 3.0000909090909094
# [0.50009091]
# [3.00009091 3.50018182]

# %%
# 点と直線をプロットする

plt.scatter(X, y)
plt.plot(np.array(X), model.predict(np.array(X)), color="orange")
plt.show()
